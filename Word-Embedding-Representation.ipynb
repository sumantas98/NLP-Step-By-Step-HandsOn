# %% [markdown]
# ## Word Embedding Technique using Embedding Layer in Keras

# %%
## Tensorflow >2.0 and keras

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
## sentences

sent = [
    'I am a good boy',
    'I am a bad boy',
    'You are good girl',
    'I like mango',
    'I am from Kolkata',
    'I love technology'
]

# %%
sent
# Out:
# ['I am a good boy',
#  'I am a bad boy',
#  'You are good girl',
#  'I like mango',
#  'I am from Kolkata',
#  'I love technology']

# %%
## Vocabulary size

voc_size = 10000

# %% [markdown]
# ## One Hot representation

# %%
## One Hot representation
onehot_repr = [one_hot(words , voc_size) for words in sent]
onehot_repr
# Out:
# [[9792, 9209, 8358, 2812, 4624],
#  [9792, 9209, 8358, 3386, 4624],
#  [1405, 9530, 2812, 2605],
#  [9792, 1977, 2030],
#  [9792, 9209, 2950, 462],
#  [9792, 7857, 264]]

# %% [markdown]
# ## Word Embedding Representation

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences  ## same number of words in every sentence
from tensorflow.keras.models import Sequential
import numpy as np

# %%
'''
Padding is import steps for word embedding representation otherwise 
index value will be discard . Here we are doing pre padding.
We can do post padding as well

''' 
sent_len = 10
embedding = pad_sequences(onehot_repr,padding='pre',maxlen=sent_len)
embedding
# Out:
# array([[   0,    0,    0,    0,    0, 9792, 9209, 8358, 2812, 4624],
#        [   0,    0,    0,    0,    0, 9792, 9209, 8358, 3386, 4624],
#        [   0,    0,    0,    0,    0,    0, 1405, 9530, 2812, 2605],
#        [   0,    0,    0,    0,    0,    0,    0, 9792, 1977, 2030],
#        [   0,    0,    0,    0,    0,    0, 9792, 9209, 2950,  462],
#        [   0,    0,    0,    0,    0,    0,    0, 9792, 7857,  264]])

# %%
## Define Dimention 
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,10,input_length=sent_len))
model.compile('adam','mse')

## adam - adam optimizer
## mse - mean squared error

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 10, 10)            100000
# =================================================================
# Total params: 100,000
# Trainable params: 100,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.predict(embedding)
# Out:
# array([[[ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [-0.04364819,  0.03255229, -0.01496198, -0.02031417,
#          -0.03967492,  0.01066654, -0.02896609, -0.01036136,
#           0.00958236,  0.03976781],
#         [ 0.03196018,  0.00019069,  0.03539642,  0.04949525,
#           0.0448291 , -0.02930281, -0.00356598,  0.04215368,
#           0.02978177, -0.01977158],
#         [ 0.04864428, -0.01000977, -0.02603872, -0.01477097,
#          -0.01001076, -0.03114974,  0.03154559, -0.03174806,
#           0.03503391, -0.00159992],
#         [ 0.03674245,  0.00750716, -0.00696893, -0.02700588,
#           0.03846294,  0.02307764,  0.02272012, -0.03404035,
#          -0.00846101,  0.01079041],
#         [-0.03187821, -0.03790794,  0.00144018, -0.01671458,
#          -0.04050915, -0.01982464, -0.00381096, -0.02994398,
#           0.01266446,  0.035846  ]],
#
#        [[ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [-0.04364819,  0.03255229, -0.01496198, -0.02031417,
#          -0.03967492,  0.01066654, -0.02896609, -0.01036136,
#           0.00958236,  0.03976781],
#         [ 0.03196018,  0.00019069,  0.03539642,  0.04949525,
#           0.0448291 , -0.02930281, -0.00356598,  0.04215368,
#           0.02978177, -0.01977158],
#         [ 0.04864428, -0.01000977, -0.02603872, -0.01477097,
#          -0.01001076, -0.03114974,  0.03154559, -0.03174806,
#           0.03503391, -0.00159992],
#         [-0.04964808,  0.04968676,  0.00505112,  0.02497169,
#          -0.00592238,  0.03366854, -0.00071851, -0.01770173,
#          -0.0426328 , -0.01948611],
#         [-0.03187821, -0.03790794,  0.00144018, -0.01671458,
#          -0.04050915, -0.01982464, -0.00381096, -0.02994398,
#           0.01266446,  0.035846  ]],
#
#        [[ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [-0.02461123, -0.02122988, -0.01996474, -0.04885254,
#           0.04142174, -0.02833004, -0.00463946, -0.02210264,
#          -0.03874569,  0.02549671],
#         [-0.02859303,  0.03738206, -0.03078259,  0.01273126,
#           0.04366546,  0.04566122,  0.04439341,  0.03397072,
#           0.00185683,  0.02319789],
#         [ 0.03674245,  0.00750716, -0.00696893, -0.02700588,
#           0.03846294,  0.02307764,  0.02272012, -0.03404035,
#          -0.00846101,  0.01079041],
#         [-0.01447828, -0.04669173,  0.0333527 , -0.02731264,
#           0.00622958, -0.00923829, -0.00240908, -0.03715492,
#           0.03619133, -0.01049212]],
#
#        [[ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [-0.04364819,  0.03255229, -0.01496198, -0.02031417,
#          -0.03967492,  0.01066654, -0.02896609, -0.01036136,
#           0.00958236,  0.03976781],
#         [-0.01329516, -0.01581608, -0.02216896,  0.04268099,
#          -0.03031949, -0.02450461, -0.01235068,  0.0404711 ,
#           0.02293794,  0.04555683],
#         [-0.02612606,  0.00899284,  0.02202294, -0.04944789,
#          -0.04496513,  0.00060204, -0.004812  ,  0.01846239,
#           0.04375204,  0.04322654]],
#
#        [[ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [-0.04364819,  0.03255229, -0.01496198, -0.02031417,
#          -0.03967492,  0.01066654, -0.02896609, -0.01036136,
#           0.00958236,  0.03976781],
#         [ 0.03196018,  0.00019069,  0.03539642,  0.04949525,
#           0.0448291 , -0.02930281, -0.00356598,  0.04215368,
#           0.02978177, -0.01977158],
#         [-0.03544427,  0.04025263, -0.03366091, -0.02204793,
#          -0.00443145,  0.01886855,  0.03174884, -0.03979552,
#           0.00743748, -0.03730579],
#         [-0.00705259,  0.02481163,  0.01214172, -0.04095649,
#          -0.03216367,  0.02471883,  0.01476995,  0.04332629,
#           0.03636569, -0.02825704]],
#
#        [[ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [ 0.00465871,  0.04092607, -0.01598113, -0.02895813,
#          -0.04308413, -0.03094381, -0.01282632, -0.04316006,
#          -0.00367897, -0.03783653],
#         [-0.04364819,  0.03255229, -0.01496198, -0.02031417,
#          -0.03967492,  0.01066654, -0.02896609, -0.01036136,
#           0.00958236,  0.03976781],
#         [ 0.03609559,  0.01134599,  0.03314838,  0.03991831,
#          -0.02140056,  0.01961365, -0.0430777 ,  0.00636903,
#           0.01436753, -0.01400262],
#         [ 0.00359899, -0.02684662,  0.03506006, -0.01616037,
#          -0.00067691, -0.02525504, -0.04242332, -0.00738367,
#           0.02639658, -0.02876246]]], dtype=float32)

# %%
embedding[1]
# Out:
# array([   0,    0,    0,    0,    0, 9792, 9209, 8358, 3386, 4624])

# %%
model.predict(embedding)[1]
# Out:
# array([[ 0.00465871,  0.04092607, -0.01598113, -0.02895813, -0.04308413,
#         -0.03094381, -0.01282632, -0.04316006, -0.00367897, -0.03783653],
#        [ 0.00465871,  0.04092607, -0.01598113, -0.02895813, -0.04308413,
#         -0.03094381, -0.01282632, -0.04316006, -0.00367897, -0.03783653],
#        [ 0.00465871,  0.04092607, -0.01598113, -0.02895813, -0.04308413,
#         -0.03094381, -0.01282632, -0.04316006, -0.00367897, -0.03783653],
#        [ 0.00465871,  0.04092607, -0.01598113, -0.02895813, -0.04308413,
#         -0.03094381, -0.01282632, -0.04316006, -0.00367897, -0.03783653],
#        [ 0.00465871,  0.04092607, -0.01598113, -0.02895813, -0.04308413,
#         -0.03094381, -0.01282632, -0.04316006, -0.00367897, -0.03783653],
#        [-0.04364819,  0.03255229, -0.01496198, -0.02031417, -0.03967492,
#          0.01066654, -0.02896609, -0.01036136,  0.00958236,  0.03976781],
#        [ 0.03196018,  0.00019069,  0.03539642,  0.04949525,  0.0448291 ,
#         -0.02930281, -0.00356598,  0.04215368,  0.02978177, -0.01977158],
#        [ 0.04864428, -0.01000977, -0.02603872, -0.01477097, -0.01001076,
#         -0.03114974,  0.03154559, -0.03174806,  0.03503391, -0.00159992],
#        [-0.04964808,  0.04968676,  0.00505112,  0.02497169, -0.00592238,
#          0.03366854, -0.00071851, -0.01770173, -0.0426328 , -0.01948611],
#        [-0.03187821, -0.03790794,  0.00144018, -0.01671458, -0.04050915,
#         -0.01982464, -0.00381096, -0.02994398,  0.01266446,  0.035846  ]],
#       dtype=float32)
